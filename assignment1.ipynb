# %%
from google.colab import files
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt


uploaded = files.upload()


img = Image.open("image.jp2").convert("L")  #  grayscale
img = np.array(img)


_, binary = cv2.threshold(img, 200, 255, cv2.THRESH_BINARY)


plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(binary, cmap='gray')
plt.title("Binary Image")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-c302fa45-db0b-4717-8dbd-3d32251e33a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c302fa45-db0b-4717-8dbd-3d32251e33a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt
uploaded = files.upload()
img = Image.open("image.jp2").convert("L")
img = np.array(img)

threshold = int(input("Enter threshold value (0-255): "))


_, binary = cv2.threshold(img, threshold, 255, cv2.THRESH_BINARY)


plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(binary, cmap="gray")
plt.title(f"Binary (Threshold = {threshold})")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-b91fd012-2c2a-4f7d-abee-ae4753a18ba7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b91fd012-2c2a-4f7d-abee-ae4753a18ba7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt

uploaded = files.upload()

img = Image.open("image.jp2").convert("L")
img = np.array(img)

threshold = int(input("Enter threshold value (0-255): "))

_, binary = cv2.threshold(img, threshold, 255, cv2.THRESH_BINARY)


plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(binary, cmap="gray")
plt.title(f"Binary (Threshold = {threshold})")
plt.axis("off")

plt.show()
# Out:
#      <input type="file" id="files-4ef60b02-badd-4b0e-8098-e7f1964a6278" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ef60b02-badd-4b0e-8098-e7f1964a6278">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
